# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaMariaCastro/curso-ia-para-economia/blob/main/clases/2_Programacion_en_Python/9_Range.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # **Range()**

# %% [markdown]
# Retorna una lista de elementos desde 0 y hasta el parámetro menos uno que se envíe dentro de los paréntesis.
#
# Retorna solo para números enteros.

# %%
# Lista de 0 a 9
range(10)

# %%
list(range(10))

# %%
list(range(10,20,3))

# %%
# Lista de 10 a 19, cada 2 elementos
list(range(10,20,2))

# %%
# Lista de 0 a 4
range(5)

# %%
list(range(5))

# %%
for i in range(5):
    print(i)
