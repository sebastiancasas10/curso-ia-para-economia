# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastiancasas10/curso-ia-para-economia/blob/main/Taller_combinacion_y_exportacion_datos_Sebastian_Casas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Taller combinacion y exportacion datos**

# %% [markdown]
# Sebastián Casas Poloche

# %%
import os
import numpy as np
import pandas as pd

# %%
# Que muestre todas las columnas
pd.options.display.max_columns = None
# En los dataframes, mostrar los float con dos decimales
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# Establecer la ruta de los datasets

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path =  '/content/drive/MyDrive/dataset_GEIH'

# %%
os.chdir(path)

# %% [markdown]
# **Datos** **de** **Julio**

# %%
df_caracteristicas_jul = pd.read_excel('JULIO/caracteristicas_julio.xlsx')
df_caracteristicas_jul.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250731    7  2025     8283143            1      1      1     10   NaN
# 1  20250731    7  2025     8283143            1      2      1     10   NaN
# 2  20250731    7  2025     8283145            1      1      1     10   NaN
#
#    CLASE      FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  P6050  \
# 0      2  27752874284     8   1      1      1     72     8.00 1,952.00      1
# 1      2  27752874284     8   1      2      2     34     8.00 1,990.00      2
# 2      2   5911013206     8   1      1      1     45     6.00 1,980.00      1
#
#    P6083  P6083S1  P6081  P6081S1  P2057  P2059  P2061  P6080 P6080S1  \
# 0      3      NaN      3      NaN      1    NaN      1      6     NaN
# 1      3      NaN      3      NaN      1    NaN      1      6     NaN
# 2      3      NaN      2      NaN      1    NaN      1      6     NaN
#
# ...

# %%
df_fuerza_jul = pd.read_excel('JULIO/fuerza_trabajo_julio.xlsx')
df_fuerza_jul.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250731    7  2025     8283143            1      1      1     50   NaN
# 1  20250731    7  2025     8283143            1      2      1     50   NaN
# 2  20250731    7  2025     8283145            1      1      1     50   NaN
#
#    CLASE      FEX_C18  DPTO   FT  FFT  PET  P6240 P6240S1  P6240S2  P6250  \
# 0      2  27752874284     8 1.00  NaN    1      1     NaN     1.00    NaN
# 1      2  27752874284     8  NaN 1.00    1      4     NaN      NaN   2.00
# 2      2   5911013206     8 1.00  NaN    1      1     NaN     1.00    NaN
#
#    P6260  P6260S1 P6260S1A1  P6260S2  P6270  P6280  P3362S1  P3362S2  P3362S3  \
# 0    NaN      NaN       NaN      NaN    NaN    NaN      NaN      NaN      NaN
# 1   2.00      NaN       NaN      NaN   2.00   2.00      NaN      NaN      NaN
# 2    NaN      NaN       NaN      NaN    NaN    NaN      NaN      NaN      NaN
#
# ...

# %%
df_hogar_jul = pd.read_excel('JULIO/hogar_julio.xlsx')
df_hogar_jul.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  HOGAR  REGIS  AREA  CLASE  \
# 0  20250731    7  2025     8283143            1      1      1   NaN      2
# 1  20250731    7  2025     8283145            1      1      1   NaN      2
# 2  20250731    7  2025     8283147            1      1      1   NaN      2
#
#        FEX_C18  DPTO  P4005  P4010  P4020  P4030S1  P4030S1A1  P4030S2  \
# 0  27752874284     8      1      5      1        1       1.00        2
# 1   5911013206     8      1      2      1        1       1.00        2
# 2  57990161862     8      1      1      2        1       1.00        2
#
#    P4030S3  P4030S4  P4030S4A1  P4030S5  P70  P5000  P5010  P5020  P5030  \
# 0        2        2        NaN        2    1      2      1      6    NaN
# 1        2        2        NaN        2    1      3      2      6    NaN
# 2        2        2        NaN        2    1      6      5      2   1.00
#
#    P5040  P5050  P5070  P5080  P5090 P5090S1  P5100         P5110      P5130  \
# ...

# %%
df_ocupados_jul = pd.read_excel('JULIO/ocupados_julio.xlsx')
df_ocupados_jul.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250731    7  2025     8283143            1      1      1     60   NaN
# 1  20250731    7  2025     8283145            1      1      1     60   NaN
# 2  20250731    7  2025     8283145            1      3      1     60   NaN
#
#    CLASE      FEX_C18  DPTO  FT  P3044S2  P6440  P6450  P6460  P6460S1  P6400  \
# 0      2  27752874284     8   1      143      1   1.00    NaN      NaN   1.00
# 1      2   5911013206     8   1      141      1   1.00    NaN      NaN   1.00
# 2      2   5911013206     8   1      141      1   1.00    NaN      NaN   1.00
#
#    P6410  P6422  P6420S2  P6424S1  P6424S2  P6424S3  P6424S5  P6426  P6430  \
# 0    NaN   1.00      NaN     2.00     2.00     2.00     2.00     84      7
# 1    NaN   1.00      NaN     2.00     2.00     2.00     2.00     48      1
# 2    NaN   1.00      NaN     2.00     2.00     2.00     2.00     48      7
#
# ...

# %%
df_caracteristicas_jul.columns
df_hogar_jul.columns
df_fuerza_jul.columns
df_ocupados_jul.columns
# Out:
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=202)

# %% [markdown]
# **Unión base de datos**

# %%
base_julio = pd.merge(df_caracteristicas_jul, df_hogar_jul, on=["DIRECTORIO","SECUENCIA_P"],
    how="left")

# %%
base_julio = pd.merge(base_julio, df_fuerza_jul, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
df_ocupados_jul = df_ocupados_jul.drop(columns=["PERIODO","MES","PER","HOGAR","REGIS","AREA","CLASE"],
    errors="ignore")

# %%
df_ocupados_jul = df_ocupados_jul.drop(columns=["FEX_C18","DPTO","FT"],
    errors="ignore")

# %%
base_julio = pd.merge(base_julio, df_ocupados_jul, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
base_julio.shape
base_julio.head()
# Out:
#    PERIODO_x  MES_x  PER_x  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR_x  REGIS_x  \
# 0   20250731      7   2025     8283143            1      1        1       10
# 1   20250731      7   2025     8283143            1      2        1       10
# 2   20250731      7   2025     8283145            1      1        1       10
# 3   20250731      7   2025     8283145            1      2        1       10
# 4   20250731      7   2025     8283145            1      3        1       10
#
#    AREA_x  CLASE_x    FEX_C18_x  DPTO_x  PT  P6016  P3271  P6040  P6030S1  \
# 0     NaN        2  27752874284       8   1      1      1     72     8.00
# 1     NaN        2  27752874284       8   1      2      2     34     8.00
# 2     NaN        2   5911013206       8   1      1      1     45     6.00
# 3     NaN        2   5911013206       8   1      2      2     50     2.00
# 4     NaN        2   5911013206       8   1      3      1     19     6.00
#
# ...

# %% [markdown]
# **Datos de agosto**

# %%
df_caracteristicas_ago = pd.read_excel('AGOSTO/caracteristicas_agosto.xlsx')
df_caracteristicas_ago.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250835    8  2025     8316823            1      1      1     10   NaN
# 1  20250835    8  2025     8316823            1      2      1     10   NaN
# 2  20250835    8  2025     8316824            1      1      1     10   NaN
#
#    CLASE      FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3
# 0    NaN    NaN      NaN      NaN      NaN      NaN      NaN    108      4
# 1    NaN   1.00      NaN     1.00     2.00     1.00     1.00     18      1
# 2    NaN   1.00      NaN     1.00     2.00     1.00     1.00     72      3
#
# ...

# %% [markdown]
# **Unión de datos**

# %%
base_agosto = pd.merge(df_caracteristicas_ago, df_hogar_ago, on=["DIRECTORIO","SECUENCIA_P"],
    how="left")

# %%
base_agosto = pd.merge(base_agosto, df_fuerza_ago, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
df_ocupados_ago = df_ocupados_ago.drop(
    columns=["PERIODO","MES","PER","HOGAR","REGIS","AREA","CLASE"],
    errors="ignore")

df_ocupados_ago = df_ocupados_ago.drop(
    columns=["FEX_C18","DPTO","FT"],
    errors="ignore")

# %%
base_agosto = pd.merge(base_agosto, df_ocupados_ago, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
base_agosto.shape
base_agosto.head()
# Out:
#    PERIODO_x  MES_x  PER_x  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR_x  REGIS_x  \
# 0   20250835      8   2025     8316823            1      1        1       10
# 1   20250835      8   2025     8316823            1      2        1       10
# 2   20250835      8   2025     8316824            1      1        1       10
# 3   20250835      8   2025     8316824            1      2        1       10
# 4   20250835      8   2025     8316825            1      1        1       10
#
#    AREA_x  CLASE_x    FEX_C18_x  DPTO_x  PT  P6016  P3271  P6040  P6030S1  \
# 0     NaN        2  21338782805       8   1      1      1     64     6.00
# 1     NaN        2  21338782805       8   1      2      2     63    10.00
# 2     NaN        2  21317266121       8   1      1      1     62     6.00
# 3     NaN        2  21317266121       8   1      2      2     50     1.00
# 4     NaN        2  39311306212       8   1      1      1     30     4.00
#
# ...

# %% [markdown]
# **Datos de septiembre**

# %%
df_caracteristicas_sep = pd.read_excel('SEPTIEMBRE/caracteristicas_septiembre.xlsx')
df_caracteristicas_sep.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250939    9  2025     8345569            1      1      1     10   NaN
# 1  20250939    9  2025     8345569            1      2      1     10   NaN
# 2  20250939    9  2025     8345570            1      1      1     10   NaN
#
#    CLASE      FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  P6050  \
# 0      2  26598435838     8   1      1      1     59     5.00 1,966.00      1
# 1      2  26598435838     8   1      2      2     62     9.00 1,962.00      2
# 2      2  54026350027     8   1      1      2     50     2.00 1,975.00      1
#
#    P6083  P6083S1  P6081  P6081S1  P2057  P2059  P2061  P6080 P6080S1  \
# 0      3      NaN      2      NaN      1    NaN      1      6     NaN
# 1      3      NaN      3      NaN      1    NaN      1      6     NaN
# 2      2      NaN      2      NaN      1    NaN      1      6     NaN
#
# ...

# %%
df_fuerza_sep = pd.read_excel('SEPTIEMBRE/fuerza_trabajo_septiembre.xlsx')
df_fuerza_sep.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250939    9  2025     8345569            1      1      1     50   NaN
# 1  20250939    9  2025     8345569            1      2      1     50   NaN
# 2  20250939    9  2025     8345570            1      1      1     50   NaN
#
#    CLASE      FEX_C18  DPTO   FT  FFT  PET  P6240 P6240S1  P6240S2  P6250  \
# 0      2  26598435838     8 1.00  NaN    1      1     NaN     1.00    NaN
# 1      2  26598435838     8  NaN 1.00    1      4     NaN      NaN   2.00
# 2      2  54026350027     8  NaN 1.00    1      4     NaN      NaN   2.00
#
#    P6260  P6260S1 P6260S1A1  P6260S2  P6270  P6280  P3362S1  P3362S2  P3362S3  \
# 0    NaN      NaN       NaN      NaN    NaN    NaN      NaN      NaN      NaN
# 1   2.00      NaN       NaN      NaN   2.00   2.00      NaN      NaN      NaN
# 2   2.00      NaN       NaN      NaN   2.00   2.00      NaN      NaN      NaN
#
# ...

# %%
df_hogar_sep = pd.read_excel('SEPTIEMBRE/hogar_septiembre.xlsx')
df_hogar_sep.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  HOGAR  REGIS  AREA  CLASE  \
# 0  20250939    9  2025     8345569            1      1      1   NaN      2
# 1  20250939    9  2025     8345570            1      1      1   NaN      2
# 2  20250939    9  2025     8345571            1      1      1   NaN      2
#
#        FEX_C18  DPTO  P4005  P4010  P4020  P4030S1  P4030S1A1  P4030S2  \
# 0  26598435838     8      1      5      1        1       0.00        2
# 1  54026350027     8      1      7      1        1       0.00        2
# 2  43734934091     8      1      5      1        1       0.00        2
#
#    P4030S3  P4030S4  P4030S4A1  P4030S5  P70  P5000  P5010  P5020  P5030  \
# 0        2        2        NaN        2    1      1      1      6    NaN
# 1        2        2        NaN        2    1      3      2      6    NaN
# 2        2        2        NaN        2    1      1      1      6    NaN
#
#    P5040  P5050  P5070  P5080  P5090 P5090S1  P5100  P5110      P5130  P5140  \
# ...

# %%
df_ocupados_sep = pd.read_excel('SEPTIEMBRE/ocupados_septiembre.xlsx')
df_ocupados_sep.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250939    9  2025     8345569            1      1      1     60   NaN
# 1  20250939    9  2025     8345570            1      2      1     60   NaN
# 2  20250939    9  2025     8345570            1      3      1     60   NaN
#
#    CLASE      FEX_C18  DPTO  FT  P3044S2  P6440  P6450  P6460  P6460S1  P6400  \
# 0      2  26598435838     8   1      113      2    NaN    NaN      NaN    NaN
# 1      2  54026350027     8   1      113      2    NaN    NaN      NaN    NaN
# 2      2  54026350027     8   1      220      2    NaN    NaN      NaN    NaN
#
#    P6410  P6422  P6420S2  P6424S1  P6424S2  P6424S3  P6424S5  P6426  P6430  \
# 0    NaN    NaN      NaN      NaN      NaN      NaN      NaN    492      4
# 1    NaN    NaN      NaN      NaN      NaN      NaN      NaN    468      4
# 2    NaN    NaN      NaN      NaN      NaN      NaN      NaN      2      4
#
# ...

# %% [markdown]
# **Unión de datos**

# %%
base_septiembre = pd.merge(df_caracteristicas_sep, df_hogar_sep, on=["DIRECTORIO","SECUENCIA_P"],
    how="left")

# %%
base_septiembre = pd.merge(base_septiembre, df_fuerza_sep, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
df_ocupados_sep = df_ocupados_sep.drop(columns=["PERIODO","MES","PER","HOGAR","REGIS","AREA","CLASE"],
    errors="ignore")

df_ocupados_sep = df_ocupados_sep.drop(columns=["FEX_C18","DPTO","FT"],
    errors="ignore")

# %%
base_septiembre = pd.merge(base_septiembre,df_ocupados_sep, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
base_septiembre.shape
base_septiembre.head()
# Out:
#    PERIODO_x  MES_x  PER_x  DIRECTORIO  SECUENCIA_P  ORDEN  HOGA
head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  HOGAR  REGIS  AREA  CLASE  \
# 0  20251044   10  2025     8374095            1      1      1   NaN      2
# 1  20251044   10  2025     8374096            1      1      1   NaN      2
# 2  20251044   10  2025     8374097            1      1      1   NaN      2
#
#        FEX_C18  DPTO  P4005  P4010  P4020  P4030S1  P4030S1A1  P4030S2  \
# 0   3609714248     8      1      1      2        1       2.00        1
# 1  20425814514     8      1      1      2        1       2.00        1
# 2  32408368672     8      1      1      2        1       2.00        1
#
#    P4030S3  P4030S4  P4030S4A1  P4030S5  P70  P5000  P5010  P5020  P5030  \
# 0        1        1       3.00        1    1      4      2      1   1.00
# 1        1        1       3.00        1    1      4      3      1   1.00
# 2        1        1       3.00        1    1      4      1      1   1.00
#
#    P5040  P5050  P5070  P5080  P5090 P5090S1      P5100          P5110  \
# ...

# %%
df_ocupados_oct = pd.read_excel('OCTUBRE/ocupados_octubre.xlsx')
df_ocupados_oct.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20251044   10  2025     8374095            1      1      1     60   NaN
# 1  20251044   10  2025     8374095            1      2      1     60   NaN
# 2  20251044   10  2025     8374096            1      1      1     60   NaN
#
#    CLASE      FEX_C18  DPTO  FT  P3044S2  P6440  P6450  P6460  P6460S1  P6400  \
# 0      2   3609714248     8   1     6512      1   2.00   2.00     4.00   2.00
# 1      2   3609714248     8   1      145      1   2.00   2.00     2.00   1.00
# 2      2  20425814514     8   1     4771      1   2.00   2.00    12.00   1.00
#
#    P6410  P6422  P6420S2  P6424S1  P6424S2  P6424S3  P6424S5  P6426  P6430  \
# 0   1.00   1.00 7,810.00     1.00     1.00     1.00     1.00      3      1
# 1    NaN   1.00      NaN     2.00     1.00     1.00     1.00      1      1
# 2    NaN   1.00      NaN     1.00     2.00     1.00     1.00    108      1
#
# ...

# %% [markdown]
# **Unión de bases**

# %%
base_octubre = pd.merge(df_caracteristicas_oct, df_hogar_oct, on=["DIRECTORIO","SECUENCIA_P"],
    how="left")

# %%
base_octubre = pd.merge( base_octubre, df_fuerza_oct, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
df_ocupados_oct = df_ocupados_oct.drop(columns=["PERIODO","MES","PER","HOGAR","REGIS","AREA","CLASE"],
    errors="ignore")

df_ocupados_oct = df_ocupados_oct.drop(columns=["FEX_C18","DPTO","FT"],
    errors="ignore")

# %%
base_octubre = pd.merge( base_octubre, df_ocupados_oct, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
base_septiembre.shape
base_septiembre.head()
# Out:
#    PERIODO_x  MES_x  PER_x  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR_x  REGIS_x  \
# 0   20250939      9   2025     8345569            1      1        1       10
# 1   20250939      9   2025     8345569            1      2        1       10
# 2   20250939      9   2025     8345570            1      1        1       10
# 3   20250939      9   2025     8345570            1      2        1       10
# 4   20250939      9   2025     8345570            1      3        1       10
#
#    AREA_x  CLASE_x    FEX_C18_x  DPTO_x  PT  P6016  P3271  P6040  P6030S1  \
# 0     NaN        2  26598435838       8   1      1      1     59     5.00
# 1     NaN        2  26598435838       8   1      2      2     62     9.00
# 2     NaN        2  54026350027       8   1      1      2     50     2.00
# 3     NaN        2  54026350027       8   1      2      1     63     4.00
# 4     NaN        2  54026350027       8   1      3      1     19    10.00
#
# ...

# %% [markdown]
# **Datos** **de noviembre**

# %%
df_caracteristicas_nov = pd.read_excel('NOVIEMBRE/caracteristicas_noviembre.xlsx')
df_caracteristicas_nov.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  
head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20251148   11  2025     8403077            1      1      1     60   NaN
# 1  20251148   11  2025     8403079            1      1      1     60   NaN
# 2  20251148   11  2025     8403081            1      1      1     60   NaN
#
#    CLASE      FEX_C18  DPTO  FT  P3044S2  P6440  P6450  P6460  P6460S1  P6400  \
# 0      2  50163641946     8   1     4651      1   2.00   1.00      NaN   1.00
# 1      2  50163641946     8   1      145      1   1.00    NaN      NaN   1.00
# 2      2  67999660447     8   1      144      1   1.00    NaN      NaN   1.00
#
#    P6410  P6422  P6420S2  P6424S1  P6424S2  P6424S3  P6424S5  P6426  P6430  \
# 0    NaN   1.00      NaN     2.00     2.00     1.00     2.00     24      1
# 1    NaN   1.00      NaN     2.00     2.00     2.00     2.00     15      7
# 2    NaN   1.00      NaN     2.00     2.00     2.00     2.00    120      7
#
# ...

# %% [markdown]
# **Unión de bases**

# %%
base_noviembre = pd.merge( df_caracteristicas_nov, df_hogar_nov, on=["DIRECTORIO","SECUENCIA_P"],
    how="left")

# %%
base_noviembre = pd.merge( base_noviembre, df_fuerza_nov, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
df_ocupados_nov = df_ocupados_nov.drop(columns=["PERIODO","MES","PER","HOGAR","REGIS","AREA","CLASE"],
    errors="ignore")

df_ocupados_nov = df_ocupados_nov.drop(columns=["FEX_C18","DPTO","FT"],
    errors="ignore")

# %%
base_noviembre = pd.merge( base_noviembre, df_ocupados_nov,on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
base_noviembre.shape
base_noviembre.head()
# Out:
#    PERIODO_x  MES_x  PER_x  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR_x  REGIS_x  \
# 0   20251148     11   2025     8403077            1      1        1       10
# 1   20251148     11   2025     8403079            1      1        1       10
# 2   20251148     11   2025     8403081            1      1        1       10
# 3   20251148     11   2025     8403081            1      2        1       10
# 4   20251148     11   2025     8403081            1      3        1       10
#
#    AREA_x  CLASE_x    FEX_C18_x  DPTO_x  PT  P6016  P3271  P6040  P6030S1  \
# 0     NaN        2  50163641946       8   1      1      1     42    12.00
# 1     NaN        2  50163641946       8   1      1      1     38     8.00
# 2     NaN        2  67999660447       8   1      1      1     45    11.00
# 3     NaN        2  67999660447       8   1      2      2     45     7.00
# 4     NaN        2  67999660447       8   1      2      1      8     8.00
#
# ...

# %% [markdown]
# **Datos de diciembre**

# %%
df_caracteristicas_dic = pd.read_excel('DICIEMBRE/caracteristicas_diciembre.xlsx')
df_caracteristicas_dic.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20251252   12  2025     8435963            1      1      1     10   NaN
# 1  20251252   12  2025     8435963            1      2      1     10   NaN
# 2  20251252   12  2025     8435963            1      3      1     10   NaN
#
#    CLASE      FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  P6050  \
# 0      2  10166138327     8   1      1      1     32     6.00 1,993.00      1
# 1      2  10166138327     8   1      2      2     28    11.00 1,997.00      2
# 2      2  10166138327     8   1      2      1      0     5.00 2,025.00      3
#
#    P6083  P6083S1  P6081  P6081S1  P2057  P2059  P2061  P6080 P6080S1  \
# 0      2      NaN      3      NaN      1    NaN      1      1  820_01
# 1      2      NaN      2      NaN      1    NaN      1      6     NaN
# 2      1     2.00      1     1.00      2   2.00      2      6     NaN
#
# ...

# %%
df_fuerza_dic = pd.read_excel('DICIEMBRE/fuerza_trabajo_diciembre.xlsx')
df_fuerza_dic.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20251252   12  2025     8435963            1      1      1     50   NaN
# 1  20251252   12  2025     8435963            1      2      1     50   NaN
# 2  20251252   12  2025     8435964            1      1      1     50   NaN
#
#    CLASE      FEX_C18  DPTO   FT  FFT  PET  P6240 P6240S1  P6240S2  P6250  \
# 0      2  10166138327     8 1.00  NaN    1      1     NaN     1.00    NaN
# 1      2  10166138327     8 1.00  NaN    1      4     NaN      NaN   2.00
# 2      2  78402590074     8 1.00  NaN    1      1     NaN     1.00    NaN
#
#    P6260  P6260S1 P6260S1A1  P6260S2  P6270  P6280  P3362S1  P3362S2  P3362S3  \
# 0    NaN      NaN       NaN      NaN    NaN    NaN      NaN      NaN      NaN
# 1   2.00      NaN       NaN      NaN   1.00    NaN      NaN      NaN      NaN
# 2    NaN      NaN       NaN      NaN    NaN    NaN      NaN      NaN      NaN
#
# ...

# %%
df_hogar_dic = pd.read_excel('DICIEMBRE/hogar_diciembre.xlsx')
df_hogar_dic.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  HOGAR  REGIS  AREA  CLASE  \
# 0  20251252   12  2025     8435963            1      1      1   NaN      2
# 1  20251252   12  2025     8435964            1      1      1   NaN      2
# 2  20251252   12  2025     8435965            1      1      1   NaN      2
#
#        FEX_C18  DPTO  P4005  P4010  P4020  P4030S1  P4030S1A1  P4030S2  \
# 0  10166138327     8      1      5      1        2        NaN        2
# 1  78402590074     8      1      5      1        2        NaN        2
# 2  78402590074     8      1      5      1        2        NaN        2
#
#    P4030S3  P4030S4  P4030S4A1  P4030S5  P70  P5000  P5010  P5020  P5030  \
# 0        2        2        NaN        2    1      2      1      5   1.00
# 1        2        2        NaN        2    1      2      1      6    NaN
# 2        2        2        NaN        2    1      1      1      6    NaN
#
#    P5040  P5050  P5070  P5080  P5090 P5090S1  P5100          P5110      P5130  \
# ...

# %%
df_ocupados_dic = pd.read_excel('DICIEMBRE/ocupados_diciembre.xlsx')
df_ocupados_dic.head(3)
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20251252   12  2025     8435963            1      1      1     60   NaN
# 1  20251252   12  2025     8435963            1      2      1     60   NaN
# 2  20251252   12  2025     8435964            1      1      1     60   NaN
#
#    CLASE      FEX_C18  DPTO  FT  P3044S2  P6440  P6450  P6460  P6460S1  P6400  \
# 0      2  10166138327     8   1      311      2    NaN    NaN      NaN    NaN
# 1      2  10166138327     8   1     5611      2    NaN    NaN      NaN    NaN
# 2      2  78402590074     8   1      311      2    NaN    NaN      NaN    NaN
#
#    P6410  P6422  P6420S2  P6424S1  P6424S2  P6424S3  P6424S5  P6426  P6430  \
# 0    NaN    NaN      NaN      NaN      NaN      NaN      NaN    204      4
# 1    NaN    NaN      NaN      NaN      NaN      NaN      NaN     60      6
# 2    NaN    NaN      NaN      NaN      NaN      NaN      NaN    360      4
#
# ...

# %% [markdown]
# **Unión de bases**

# %%
base_diciembre = pd.merge( df_caracteristicas_dic, df_hogar_dic, on=["DIRECTORIO","SECUENCIA_P"],
    how="left")

# %%
base_diciembre = pd.merge( base_diciembre, df_fuerza_dic, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
df_ocupados_dic = df_ocupados_dic.drop( columns=["PERIODO","MES","PER","HOGAR","REGIS","AREA","CLASE"],
    errors="ignore")

df_ocupados_dic = df_ocupados_dic.drop( columns=["FEX_C18","DPTO","FT"],
    errors="ignore")

# %%
base_diciembre = pd.merge( base_diciembre, df_ocupados_dic, on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left")

# %%
base_diciembre.shape
base_diciembre.head()
# Out:
#    PERIODO_x  MES_x  PER_x  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR_x  REGIS_x  \
# 0   20251252     12   2025     8435963            1      1        1       10
# 1   20251252     12   2025     8435963            1      2        1       10
# 2   20251252     12   2025     8435963            1      3        1       10
# 3   20251252     12   2025     8435964            1      1        1       10
# 4   20251252     12   2025     8435965            1      1        1       10
#
#    AREA_x  CLASE_x    FEX_C18_x  DPTO_x  PT  P6016  P3271  P6040  P6030S1  \
# 0     NaN        2  10166138327       8   1      1      1     32     6.00
# 1     NaN        2  10166138327       8   1      2      2     28    11.00
# 2     NaN        2  10166138327       8   1      2      1      0     5.00
# 3     NaN        2  78402590074       8   1      1      1     75     8.00
# 4     NaN        2  78402590074       8   1      1      1     68    11.00
#
# ...

# %% [markdown]
# **Unión de la base 2025**

# %%
base_2025 = pd.concat([base_julio, base_agosto, base_septiembre, base_octubre,
    base_noviembre, base_diciembre], ignore_index=True)

# %%
base_2025.shape
# Out:
# (409127, 330)

# %%
base_2025.head()
# Out:
#    PERIODO_x  MES_x  PER_x  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR_x  REGIS_x  \
# 0   20250731      7   2025     8283143            1      1        1       10
# 1   20250731      7   2025     8283143            1      2        1       10
# 2   20250731      7   2025     8283145            1      1        1       10
# 3   20250731      7   2025     8283145            1      2        1       10
# 4   20250731      7   2025     8283145            1      3        1       10
#
#    AREA_x  CLASE_x    FEX_C18_x  DPTO_x  PT  P6016  P3271  P6040  P6030S1  \
# 0     NaN        2  27752874284       8   1      1      1     72     8.00
# 1     NaN        2  27752874284       8   1      2      2     34     8.00
# 2     NaN        2   5911013206       8   1      1      1     45     6.00
# 3     NaN        2   5911013206       8   1      2      2     50     2.00
# 4     NaN        2   5911013206       8   1      3      1     19     6.00
#
# ...

# %%
base_2025 = base_2025.rename(columns={'PERIODO_x':'PERIODO','MES_x':'MES',
    'PER_x':'PER','HOGAR_x':'HOGAR','REGIS_x':'REGIS','AREA_x':'AREA',
    'CLASE_x':'CLASE','FEX_C18_x':'FEX_C18','DPTO_x':'DPTO'})

# %%
base_2025.columns
# Out:
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO', 'RAMA2D_R4',
#        'RAMA4D_R4', 'OFICIO_C8', 'DESCRIPCION_CIIU'],
#       dtype='object', length=331)

# %%
base_2025.head()
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250731    7  2025     8283143            1      1      1     10   NaN
# 1  20250731    7  2025     8283143            1      2      1     10   NaN
# 2  20250731    7  2025     8283145            1      1      1     10   NaN
# 3  20250731    7  2025     8283145            1      2      1     10   NaN
# 4  20250731    7  2025     8283145            1      3      1     10   NaN
#
#    CLASE      FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  P6050  \
# 0      2  27752874284     8   1      1      1     72     8.00 1,952.00      1
# 1      2  27752874284     8   1      2      2     34     8.00 1,990.00      2
# 2      2   5911013206     8   1      1      1     45     6.00 1,980.00      1
# 3      2   5911013206     8   1      2      2     50     2.00 1,975.00      2
# 4      2   5911013206     8   1      3      1     19     6.00 2,006.00      3
#
# ...

# %% [markdown]
# **Descripción del CIIU**

# %%
ciiu = pd.read_excel('/content/drive/MyDrive/dataset_GEIH/2025-01-14 Correlativa CIIU Rev4.xlsx',
                     sheet_name='CIIU 2022')

# %%
ciiu.columns
# Out:
# Index(['RAMA4D_R4', 'DESCRIPCION_CIIU'], dtype='object')

# %%
ciiu.head()
# Out:
#    RAMA4D_R4              DESCRIPCION_CIIU
# 0          0                   Desconocido
# 1         10  Actividad Personas Naturales
# 2         20  Actividad Personas Naturales
# 3         81  Actividad Personas Naturales
# 4         82  Actividad Personas Naturales

# %%
ciiu = ciiu[['RAMA4D_R4','DESCRIPCION_CIIU']]

# %%
base_2025 = pd.merge(base_2025, ciiu, on='RAMA4D_R4', how='left')

# %%
base_2025 = base_2025.drop(columns=['DESCRIPCION_CIIU_y'])

# %%
base_2025 = base_2025.rename(columns={'DESCRIPCION_CIIU_x':'DESCRIPCION_CIIU'})

# %%
base_2025[['RAMA4D_R4','DESCRIPCION_CIIU']].head()
# Out:
#    RAMA4D_R4                  DESCRIPCION_CIIU
# 0     143.00           Cría de ovejas y cabras
# 1        NaN                               NaN
# 2     141.00  Cría de ganado bovino y bufalino
# 3        NaN                               NaN
# 4     141.00  Cría de ganado bovino y bufalino

# %% [markdown]
# **Archivo Divipola**

# %%
divipola = pd.read_excel( '/content/drive/MyDrive/dataset_GEIH/2025-01-14 DIVIPOLA.xlsx',
    sheet_name='Departamentos', skiprows=8)

# %%
divipola.head()
divipola.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1'], dtype='object')

# %%
divipola = divipola.rename(columns={'Unnamed: 0': 'DPTO','Unnamed: 1': 'NOMBRE_DPTO'})

# %%
divipola = divipola.drop(index=0)

# %%
divipola = divipola[['DPTO','NOMBRE_DPTO']]

# %%
base_2025 = pd.merge( base_2025, divipola, on='DPTO',how='left')

# %%
[c for c in base_2025.columns if "DPTO" in c]
# Out:
# ['DPTO', 'DPTO_y', 'DPTO']

# %%
base_2025 = base_2025.loc[:, ~base_2025.columns.duplicated()]
base_2025 = base_2025.drop(columns=['DPTO_y'], errors='ignore')

# %%
[c for c in base_2025.columns if "DPTO" in c]
# Out:
# ['DPTO']

# %%
base_2025[['DPTO','NOMBRE_DPTO']].head()
# Out:
#   DPTO NOMBRE_DPTO
# 0    8         NaN
# 1    8         NaN
# 2    8         NaN
# 3    8         NaN
# 4    8         NaN

# %%
base_2025.shape
# Out:
# (409127, 322)

# %% [markdown]
# **Limpiar columnas duplicadas**

# %%
base_2025 = base_2025.loc[:, ~base_2025.columns.str.endswith('_y')]

# %%
base_2025.columns = base_2025.columns.str.replace('_x','')

# %%
base_2025 = base_2025.loc[:, ~base_2025.columns.duplicated()]

# %%
base_2025.shape
# Out:
# (409127, 314)

# %% [markdown]
# **Exportar la base final**

# %%
base_2025.to_csv('/content/drive/MyDrive/dataset_GEIH/base_GEIH_2025.csv', index=False)
